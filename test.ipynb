# %%
import sys
sys.path.append("/home/ycui/Documents/TSRLproject_JPMorgan/custom_bins/")
import mcmc as tfpmcmc

# %%
from tensorflow_probability.python.mcmc.internal import leapfrog_integrator as leapfrog_impl

# %%
leapfrog_impl
# Out:
# <module 'tensorflow_probability.python.mcmc.internal.leapfrog_integrator' from '/home/ycui/.conda/envs/tf/lib/python3.10/site-packages/tensorflow_probability/python/mcmc/internal/leapfrog_integrator.py'>

# %%
from tensorflow_probability.python.mcmc.internal import leapfrog_integrator as leapfrog_impl

# %%
leapfrog_impl
# Out:
# <module 'tensorflow_probability.python.mcmc.internal.leapfrog_integrator' from '/home/ycui/.conda/envs/tf/lib/python3.10/site-packages/tensorflow_probability/python/mcmc/internal/leapfrog_integrator.py'>

# %%
tfpmcmc
# Out:
# <module 'mcmc' from '/home/ycui/Documents/TSRLproject_JPMorgan/custom_bins/probability/tensorflow_probability/python/mcmc/__init__.py'>
